# %% [markdown]
# <a href="https://colab.research.google.com/github/suajeong52/CNN/blob/main/CIFAR10_ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
NUM_CLASSES = 10

x_train = x_train.astype('float32')/255.
x_test  = x_test.astype('float32')/255.

y_train = to_categorical(y_train)
y_test  = to_categorical(y_test)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
# !pip install git+https://www.github.com/keras-team/keras-contrib.git
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-ysdochr5
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-ysdochr5
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from keras-contrib==2.0.8) (2.8.0)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-py3-none-any.whl size=101077 sha256=e4372b76884032e1b5768af34d2fb53f6c2dde24970ccac4e8c01d51db527b3b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-brs8nv_m/wheels/bb/1f/f2/b57495012683b6b20bbae94a3915ec79753111452d79886abc
# Successfully built keras-contrib
# Installing collected packages: keras-contrib
# Successfully installed keras-contrib-2.0.8

# %%
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout, Concatenate, Layer, InputSpec, Activation, LeakyReLU
from tensorflow.keras.activations import sigmoid 
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError 
from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization
from tensorflow.keras.layers import UpSampling2D, Conv2D, Conv2DTranspose
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.layers import add

from tensorflow.keras.callbacks import Callback, LearningRateScheduler
from tensorflow.keras.callbacks import ModelCheckpoint
import os

# %%
class CustomCallback(Callback):
    
    def __init__(self, run_folder, print_every_n_batches, initial_epoch, vae, ):
        self.epoch = initial_epoch
        self.run_folder = run_folder
        self.print_every_n_batches = print_every_n_batches
        self.vae = vae

    def on_batch_end(self, batch, logs={}):  
      a=0
    #  if batch % self.print_every_n_batches == 0:
    #    print(batch)
     #     self.model.predict()
     #     potential_by_cnn =  model.predict(X_test)


     #       z_new = np.random.normal(size = (1,self.vae.z_dim))
     #       reconst = self.vae.decoder.predict(np.array(z_new))[0].squeeze()

      #      filepath = os.path.join(self.run_folder, 'images', 'img_' + str(self.epoch).zfill(3) + '_' + str(batch) + '.jpg')
      #      if len(reconst.shape) == 2:
      #          plt.imsave(filepath, reconst, cmap='gray_r')
      #      else:
      #          plt.imsave(filepath, reconst)

    def on_epoch_begin(self, epoch, logs={}):
        self.epoch += 1



def step_decay_schedule(initial_lr, decay_factor=0.5, step_size=1):
    '''
    Wrapper function to create a LearningRateScheduler with step decay schedule.
    '''
    def schedule(epoch):
        new_lr = initial_lr * (decay_factor ** np.floor(epoch/step_size))
        
        return new_lr

    return LearningRateScheduler(schedule)

# %%
weight_init = RandomNormal(mean=0., stddev=0.02)

def conv7s1(layer_input, filters, final):
  y = ReflectionPadding2D(padding =(3,3))(layer_input)
  y = Conv2D(filters, kernel_size=(7,7), strides=1, padding='valid', kernel_initializer = weight_init)(y)
  if final:
    y = sigmoid(y) # Activation('tanh')(y)
  else:
    y = InstanceNormalization(axis = -1, center = False, scale = False)(y)
    #y = Activation('relu')(y)
    y = LeakyReLU()(y)
  return y

def downsample(layer_input,filters):
  y = Conv2D(filters, kernel_size=(3,3), strides=2, padding='same', kernel_initializer = weight_init)(layer_input)
  y = InstanceNormalization(axis = -1, center = False, scale = False)(y)
  #y = Activation('relu')(y)
  y = LeakyReLU()(y)
  return y

def residual(layer_input, filters):
  shortcut = layer_input
  y = ReflectionPadding2D(padding =(1,1))(layer_input)
  y = Conv2D(filters, kernel_size=(3, 3), strides=1, padding='valid', kernel_initializer = weight_init)(y)
  y = InstanceNormalization(axis = -1, center = False, scale = False)(y)
  #y = Activation('relu')(y)
  y = LeakyReLU()(y)
            
  y = ReflectionPadding2D(padding =(1,1))(y)
  y = Conv2D(filters, kernel_size=(3, 3), strides=1, padding='valid', kernel_initializer = weight_init)(y)
  y = InstanceNormalization(axis = -1, center = False, scale = False)(y)

  return add([shortcut, y])

def upsample(layer_input,filters):
  y = Conv2DTranspose(filters, kernel_size=(3, 3), strides=2, padding='same', kernel_initializer = weight_init)(layer_input)
  y = InstanceNormalization(axis = -1, center = False, scale = False)(y)
  #y = Activation('relu')(y)
  y = LeakyReLU()(y)
    
  return y

class ReflectionPadding2D(Layer):
    def __init__(self, padding=(1, 1), **kwargs):
        self.padding = tuple(padding)
        self.input_spec = [InputSpec(ndim=4)]
        super(ReflectionPadding2D, self).__init__(**kwargs)

    def compute_output_shape(self, s):
        """ If you are using "channels_last" configuration"""
        return (s[0], s[1] + 2 * self.padding[0], s[2] + 2 * self.padding[1], s[3])

    def call(self, x, mask=None):
        w_pad,h_pad = self.padding
        return tf.pad(x, [[0,0], [h_pad,h_pad], [w_pad,w_pad], [0,0] ], 'REFLECT')

# %%
gen_n_filters = 8

# Image input
img = Input(shape=(32,32,3))

y = conv7s1(img, gen_n_filters, False)


y = downsample(y, gen_n_filters * 2)
for i in range(10):
  y = residual(y, gen_n_filters * 2)


y = downsample(y, gen_n_filters * 2)
for i in range(10):
  y = residual(y, gen_n_filters * 2)

y = Flatten()(y)

y = Dense(128, activation ='relu')(y)
y = LeakyReLU()(y)

output = Dense(10, activation = 'softmax')(y)

   
model = Model(img, output)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  reflection_padding2d (Reflecti  (None, 38, 38, 3)   0           ['input_1[0][0]']
#  onPadding2D)
#
#  conv2d (Conv2D)                (None, 32, 32, 8)    1184        ['reflection_padding2d[0][0]']
#
#  instance_normalization (Instan  (None, 32, 32, 8)   0           ['conv2d[0][0]']
#  ceNormalization)
#
#  leaky_re_lu (LeakyReLU)        (None, 32, 32, 8)    0           ['instance_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 16)   1168        ['leaky_re_lu[0][0]']
#
#  instance_normalization_1 (Inst  (None, 16, 16, 16)  0           ['conv2d_1[0][0]']
#  anceNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 16, 16, 16)   0           ['instance_normalization_1[0][0]'
#                                                                  ]
#
#  reflection_padding2d_1 (Reflec  (None, 18, 18, 16)  0           ['leaky_re_lu_1[0][0]']
#  tionPadding2D)
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 16)   2320        ['reflection_padding2d_1[0][0]']
#
#  instance_normalization_2 (Inst  (None, 16, 16, 16)  0           ['conv2d_2[0][0]']
#  anceNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 16, 16, 16)   0           ['instance_normalization_2[0][0]'
#                                                                  ]
#
#  reflection_padding2d_2 (Reflec  (None, 18, 18, 16)  0           ['leaky_re_lu_2[0][0]']
#  tionPadding2D)
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 16)   2320        ['reflection_padding2d_2[0][0]']
#
#  instance_normalization_3 (Inst  (None, 16, 16, 16)  0           ['conv2d_3[0][0]']
#  anceNormalization)
#
#  add (Add)                      (None, 16, 16, 16)   0           ['leaky_re_lu_1[0][0]',
#                                                                   'instance_normalization_3[0][0]'
#                                                                  ]
#
#  reflection_padding2d_3 (Reflec  (None, 18, 18, 16)  0           ['add[0][0]']
#  tionPadding2D)
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 16)   2320        ['reflection_padding2d_3[0][0]']
#
#  instance_normalization_4 (Inst  (None, 16, 16, 16)  0           ['conv2d_4[0][0]']
#  anceNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 16, 16, 16)   0           ['instance_normalization_4[0][0]'
#                                                                  ]
#
#  reflection_padding2d_4 (Reflec  (None, 18, 18, 16)  0           ['leaky_re_lu_3[0][0]']
#  tionPadding2D)
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 16)   2320        ['reflection_padding2d_4[0][0]']
#
#  instance_normalization_5 (Inst  (None, 16, 16, 16)  0           ['conv2d_5[0][0]']
#  anceNormalization)
#
#  add_1 (Add)                    (None, 16, 16, 16)   0           ['add[0][0]',
#                                                                   'instance_normalization_5[0][0]'
#                                                                  ]
#
#  reflection_padding2d_5 (Reflec  (None, 18, 18, 16)  0           ['add_1[0][0]']
#  tionPadding2D)
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 16)   2320        ['reflection_padding2d_5[0][0]']
#
#  instance_normalization_6 (Inst  (None, 16, 16, 16)  0           ['conv2d_6[0][0]']
#  anceNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 16, 16, 16)   0           ['instance_normalization_6[0][0]'
#                                                                  ]
#
#  reflection_padding2d_6 (Reflec  (None, 18, 18, 16)  0           ['leaky_re_lu_4[0][0]']
#  tionPadding2D)
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 16)   2320        ['reflection_padding2d_6[0][0]']
#
#  instance_normalization_7 (Inst  (None, 16, 16, 16)  0           ['conv2d_7[0][0]']
#  anceNormalization)
#
#  add_2 (Add)                    (None, 16, 16, 16)   0           ['add_1[0][0]',
#                                                                   'instance_normalization_7[0][0]'
#                                                                  ]
#
#  reflection_padding2d_7 (Reflec  (None, 18, 18, 16)  0           ['add_2[0][0]']
#  tionPadding2D)
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 16)   2320        ['reflection_padding2d_7[0][0]']
#
#  instance_normalization_8 (Inst  (None, 16, 16, 16)  0           ['conv2d_8[0][0]']
#  anceNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 16, 16, 16)   0           ['instance_normalization_8[0][0]'
#                                                                  ]
#
#  reflection_padding2d_8 (Reflec  (None, 18, 18, 16)  0           ['leaky_re_lu_5[0][0]']
#  tionPadding2D)
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 16)   2320        ['reflection_padding2d_8[0][0]']
#
#  instance_normalization_9 (Inst  (None, 16, 16, 16)  0           ['conv2d_9[0][0]']
#  anceNormalization)
#
#  add_3 (Add)                    (None, 16, 16, 16)   0           ['add_2[0][0]',
#                                                                   'instance_normalization_9[0][0]'
#                                                                  ]
#
#  reflection_padding2d_9 (Reflec  (None, 18, 18, 16)  0           ['add_3[0][0]']
#  tionPadding2D)
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 16)   2320        ['reflection_padding2d_9[0][0]']
#
#  instance_normalization_10 (Ins  (None, 16, 16, 16)  0           ['conv2d_10[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 16, 16, 16)   0           ['instance_normalization_10[0][0]
#                                                                  ']
#
#  reflection_padding2d_10 (Refle  (None, 18, 18, 16)  0           ['leaky_re_lu_6[0][0]']
#  ctionPadding2D)
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 16)   2320        ['reflection_padding2d_10[0][0]']
#
#  instance_normalization_11 (Ins  (None, 16, 16, 16)  0           ['conv2d_11[0][0]']
#  tanceNormalization)
#
#  add_4 (Add)                    (None, 16, 16, 16)   0           ['add_3[0][0]',
#                                                                   'instance_normalization_11[0][0]
#                                                                  ']
#
#  reflection_padding2d_11 (Refle  (None, 18, 18, 16)  0           ['add_4[0][0]']
#  ctionPadding2D)
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 16)   2320        ['reflection_padding2d_11[0][0]']
#
#  instance_normalization_12 (Ins  (None, 16, 16, 16)  0           ['conv2d_12[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 16, 16, 16)   0           ['instance_normalization_12[0][0]
#                                                                  ']
#
#  reflection_padding2d_12 (Refle  (None, 18, 18, 16)  0           ['leaky_re_lu_7[0][0]']
#  ctionPadding2D)
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 16)   2320        ['reflection_padding2d_12[0][0]']
#
#  instance_normalization_13 (Ins  (None, 16, 16, 16)  0           ['conv2d_13[0][0]']
#  tanceNormalization)
#
#  add_5 (Add)                    (None, 16, 16, 16)   0           ['add_4[0][0]',
#                                                                   'instance_normalization_13[0][0]
#                                                                  ']
#
#  reflection_padding2d_13 (Refle  (None, 18, 18, 16)  0           ['add_5[0][0]']
#  ctionPadding2D)
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 16)   2320        ['reflection_padding2d_13[0][0]']
#
#  instance_normalization_14 (Ins  (None, 16, 16, 16)  0           ['conv2d_14[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 16, 16, 16)   0           ['instance_normalization_14[0][0]
#                                                                  ']
#
#  reflection_padding2d_14 (Refle  (None, 18, 18, 16)  0           ['leaky_re_lu_8[0][0]']
#  ctionPadding2D)
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 16)   2320        ['reflection_padding2d_14[0][0]']
#
#  instance_normalization_15 (Ins  (None, 16, 16, 16)  0           ['conv2d_15[0][0]']
#  tanceNormalization)
#
#  add_6 (Add)                    (None, 16, 16, 16)   0           ['add_5[0][0]',
#                                                                   'instance_normalization_15[0][0]
#                                                                  ']
#
#  reflection_padding2d_15 (Refle  (None, 18, 18, 16)  0           ['add_6[0][0]']
#  ctionPadding2D)
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 16)   2320        ['reflection_padding2d_15[0][0]']
#
#  instance_normalization_16 (Ins  (None, 16, 16, 16)  0           ['conv2d_16[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)      (None, 16, 16, 16)   0           ['instance_normalization_16[0][0]
#                                                                  ']
#
#  reflection_padding2d_16 (Refle  (None, 18, 18, 16)  0           ['leaky_re_lu_9[0][0]']
#  ctionPadding2D)
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 16)   2320        ['reflection_padding2d_16[0][0]']
#
#  instance_normalization_17 (Ins  (None, 16, 16, 16)  0           ['conv2d_17[0][0]']
#  tanceNormalization)
#
#  add_7 (Add)                    (None, 16, 16, 16)   0           ['add_6[0][0]',
#                                                                   'instance_normalization_17[0][0]
#                                                                  ']
#
#  reflection_padding2d_17 (Refle  (None, 18, 18, 16)  0           ['add_7[0][0]']
#  ctionPadding2D)
#
#  conv2d_18 (Conv2D)             (None, 16, 16, 16)   2320        ['reflection_padding2d_17[0][0]']
#
#  instance_normalization_18 (Ins  (None, 16, 16, 16)  0           ['conv2d_18[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 16, 16, 16)   0           ['instance_normalization_18[0][0]
#                                                                  ']
#
#  reflection_padding2d_18 (Refle  (None, 18, 18, 16)  0           ['leaky_re_lu_10[0][0]']
#  ctionPadding2D)
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 16)   2320        ['reflection_padding2d_18[0][0]']
#
#  instance_normalization_19 (Ins  (None, 16, 16, 16)  0           ['conv2d_19[0][0]']
#  tanceNormalization)
#
#  add_8 (Add)                    (None, 16, 16, 16)   0           ['add_7[0][0]',
#                                                                   'instance_normalization_19[0][0]
#                                                                  ']
#
#  reflection_padding2d_19 (Refle  (None, 18, 18, 16)  0           ['add_8[0][0]']
#  ctionPadding2D)
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 16)   2320        ['reflection_padding2d_19[0][0]']
#
#  instance_normalization_20 (Ins  (None, 16, 16, 16)  0           ['conv2d_20[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)     (None, 16, 16, 16)   0           ['instance_normalization_20[0][0]
#                                                                  ']
#
#  reflection_padding2d_20 (Refle  (None, 18, 18, 16)  0           ['leaky_re_lu_11[0][0]']
#  ctionPadding2D)
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 16)   2320        ['reflection_padding2d_20[0][0]']
#
#  instance_normalization_21 (Ins  (None, 16, 16, 16)  0           ['conv2d_21[0][0]']
#  tanceNormalization)
#
#  add_9 (Add)                    (None, 16, 16, 16)   0           ['add_8[0][0]',
#                                                                   'instance_normalization_21[0][0]
#                                                                  ']
#
#  conv2d_22 (Conv2D)             (None, 8, 8, 16)     2320        ['add_9[0][0]']
#
#  instance_normalization_22 (Ins  (None, 8, 8, 16)    0           ['conv2d_22[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)     (None, 8, 8, 16)     0           ['instance_normalization_22[0][0]
#                                                                  ']
#
#  reflection_padding2d_21 (Refle  (None, 10, 10, 16)  0           ['leaky_re_lu_12[0][0]']
#  ctionPadding2D)
#
#  conv2d_23 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_21[0][0]']
#
#  instance_normalization_23 (Ins  (None, 8, 8, 16)    0           ['conv2d_23[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)     (None, 8, 8, 16)     0           ['instance_normalization_23[0][0]
#                                                                  ']
#
#  reflection_padding2d_22 (Refle  (None, 10, 10, 16)  0           ['leaky_re_lu_13[0][0]']
#  ctionPadding2D)
#
#  conv2d_24 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_22[0][0]']
#
#  instance_normalization_24 (Ins  (None, 8, 8, 16)    0           ['conv2d_24[0][0]']
#  tanceNormalization)
#
#  add_10 (Add)                   (None, 8, 8, 16)     0           ['leaky_re_lu_12[0][0]',
#                                                                   'instance_normalization_24[0][0]
#                                                                  ']
#
#  reflection_padding2d_23 (Refle  (None, 10, 10, 16)  0           ['add_10[0][0]']
#  ctionPadding2D)
#
#  conv2d_25 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_23[0][0]']
#
#  instance_normalization_25 (Ins  (None, 8, 8, 16)    0           ['conv2d_25[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_14 (LeakyReLU)     (None, 8, 8, 16)     0           ['instance_normalization_25[0][0]
#                                                                  ']
#
#  reflection_padding2d_24 (Refle  (None, 10, 10, 16)  0           ['leaky_re_lu_14[0][0]']
#  ctionPadding2D)
#
#  conv2d_26 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_24[0][0]']
#
#  instance_normalization_26 (Ins  (None, 8, 8, 16)    0           ['conv2d_26[0][0]']
#  tanceNormalization)
#
#  add_11 (Add)                   (None, 8, 8, 16)     0           ['add_10[0][0]',
#                                                                   'instance_normalization_26[0][0]
#                                                                  ']
#
#  reflection_padding2d_25 (Refle  (None, 10, 10, 16)  0           ['add_11[0][0]']
#  ctionPadding2D)
#
#  conv2d_27 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_25[0][0]']
#
#  instance_normalization_27 (Ins  (None, 8, 8, 16)    0           ['conv2d_27[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_15 (LeakyReLU)     (None, 8, 8, 16)     0           ['instance_normalization_27[0][0]
#                                                                  ']
#
#  reflection_padding2d_26 (Refle  (None, 10, 10, 16)  0           ['leaky_re_lu_15[0][0]']
#  ctionPadding2D)
#
#  conv2d_28 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_26[0][0]']
#
#  instance_normalization_28 (Ins  (None, 8, 8, 16)    0           ['conv2d_28[0][0]']
#  tanceNormalization)
#
#  add_12 (Add)                   (None, 8, 8, 16)     0           ['add_11[0][0]',
#                                                                   'instance_normalization_28[0][0]
#                                                                  ']
#
#  reflection_padding2d_27 (Refle  (None, 10, 10, 16)  0           ['add_12[0][0]']
#  ctionPadding2D)
#
#  conv2d_29 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_27[0][0]']
#
#  instance_normalization_29 (Ins  (None, 8, 8, 16)    0           ['conv2d_29[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)     (None, 8, 8, 16)     0           ['instance_normalization_29[0][0]
#                                                                  ']
#
#  reflection_padding2d_28 (Refle  (None, 10, 10, 16)  0           ['leaky_re_lu_16[0][0]']
#  ctionPadding2D)
#
#  conv2d_30 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_28[0][0]']
#
#  instance_normalization_30 (Ins  (None, 8, 8, 16)    0           ['conv2d_30[0][0]']
#  tanceNormalization)
#
#  add_13 (Add)                   (None, 8, 8, 16)     0           ['add_12[0][0]',
#                                                                   'instance_normalization_30[0][0]
#                                                                  ']
#
#  reflection_padding2d_29 (Refle  (None, 10, 10, 16)  0           ['add_13[0][0]']
#  ctionPadding2D)
#
#  conv2d_31 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_29[0][0]']
#
#  instance_normalization_31 (Ins  (None, 8, 8, 16)    0           ['conv2d_31[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_17 (LeakyReLU)     (None, 8, 8, 16)     0           ['instance_normalization_31[0][0]
#                                                                  ']
#
#  reflection_padding2d_30 (Refle  (None, 10, 10, 16)  0           ['leaky_re_lu_17[0][0]']
#  ctionPadding2D)
#
#  conv2d_32 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_30[0][0]']
#
#  instance_normalization_32 (Ins  (None, 8, 8, 16)    0           ['conv2d_32[0][0]']
#  tanceNormalization)
#
#  add_14 (Add)                   (None, 8, 8, 16)     0           ['add_13[0][0]',
#                                                                   'instance_normalization_32[0][0]
#                                                                  ']
#
#  reflection_padding2d_31 (Refle  (None, 10, 10, 16)  0           ['add_14[0][0]']
#  ctionPadding2D)
#
#  conv2d_33 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_31[0][0]']
#
#  instance_normalization_33 (Ins  (None, 8, 8, 16)    0           ['conv2d_33[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_18 (LeakyReLU)     (None, 8, 8, 16)     0           ['instance_normalization_33[0][0]
#                                                                  ']
#
#  reflection_padding2d_32 (Refle  (None, 10, 10, 16)  0           ['leaky_re_lu_18[0][0]']
#  ctionPadding2D)
#
#  conv2d_34 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_32[0][0]']
#
#  instance_normalization_34 (Ins  (None, 8, 8, 16)    0           ['conv2d_34[0][0]']
#  tanceNormalization)
#
#  add_15 (Add)                   (None, 8, 8, 16)     0           ['add_14[0][0]',
#                                                                   'instance_normalization_34[0][0]
#                                                                  ']
#
#  reflection_padding2d_33 (Refle  (None, 10, 10, 16)  0           ['add_15[0][0]']
#  ctionPadding2D)
#
#  conv2d_35 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_33[0][0]']
#
#  instance_normalization_35 (Ins  (None, 8, 8, 16)    0           ['conv2d_35[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_19 (LeakyReLU)     (None, 8, 8, 16)     0           ['instance_normalization_35[0][0]
#                                                                  ']
#
#  reflection_padding2d_34 (Refle  (None, 10, 10, 16)  0           ['leaky_re_lu_19[0][0]']
#  ctionPadding2D)
#
#  conv2d_36 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_34[0][0]']
#
#  instance_normalization_36 (Ins  (None, 8, 8, 16)    0           ['conv2d_36[0][0]']
#  tanceNormalization)
#
#  add_16 (Add)                   (None, 8, 8, 16)     0           ['add_15[0][0]',
#                                                                   'instance_normalization_36[0][0]
#                                                                  ']
#
#  reflection_padding2d_35 (Refle  (None, 10, 10, 16)  0           ['add_16[0][0]']
#  ctionPadding2D)
#
#  conv2d_37 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_35[0][0]']
#
#  instance_normalization_37 (Ins  (None, 8, 8, 16)    0           ['conv2d_37[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_20 (LeakyReLU)     (None, 8, 8, 16)     0           ['instance_normalization_37[0][0]
#                                                                  ']
#
#  reflection_padding2d_36 (Refle  (None, 10, 10, 16)  0           ['leaky_re_lu_20[0][0]']
#  ctionPadding2D)
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_36[0][0]']
#
#  instance_normalization_38 (Ins  (None, 8, 8, 16)    0           ['conv2d_38[0][0]']
#  tanceNormalization)
#
#  add_17 (Add)                   (None, 8, 8, 16)     0           ['add_16[0][0]',
#                                                                   'instance_normalization_38[0][0]
#                                                                  ']
#
#  reflection_padding2d_37 (Refle  (None, 10, 10, 16)  0           ['add_17[0][0]']
#  ctionPadding2D)
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_37[0][0]']
#
#  instance_normalization_39 (Ins  (None, 8, 8, 16)    0           ['conv2d_39[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_21 (LeakyReLU)     (None, 8, 8, 16)     0           ['instance_normalization_39[0][0]
#                                                                  ']
#
#  reflection_padding2d_38 (Refle  (None, 10, 10, 16)  0           ['leaky_re_lu_21[0][0]']
#  ctionPadding2D)
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_38[0][0]']
#
#  instance_normalization_40 (Ins  (None, 8, 8, 16)    0           ['conv2d_40[0][0]']
#  tanceNormalization)
#
#  add_18 (Add)                   (None, 8, 8, 16)     0           ['add_17[0][0]',
#                                                                   'instance_normalization_40[0][0]
#                                                                  ']
#
#  reflection_padding2d_39 (Refle  (None, 10, 10, 16)  0           ['add_18[0][0]']
#  ctionPadding2D)
#
#  conv2d_41 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_39[0][0]']
#
#  instance_normalization_41 (Ins  (None, 8, 8, 16)    0           ['conv2d_41[0][0]']
#  tanceNormalization)
#
#  leaky_re_lu_22 (LeakyReLU)     (None, 8, 8, 16)     0           ['instance_normalization_41[0][0]
#                                                                  ']
#
#  reflection_padding2d_40 (Refle  (None, 10, 10, 16)  0           ['leaky_re_lu_22[0][0]']
#  ctionPadding2D)
#
#  conv2d_42 (Conv2D)             (None, 8, 8, 16)     2320        ['reflection_padding2d_40[0][0]']
#
#  instance_normalization_42 (Ins  (None, 8, 8, 16)    0           ['conv2d_42[0][0]']
#  tanceNormalization)
#
#  add_19 (Add)                   (None, 8, 8, 16)     0           ['add_18[0][0]',
#                                                                   'instance_normalization_42[0][0]
#                                                                  ']
#
#  flatten (Flatten)              (None, 1024)         0           ['add_19[0][0]']
#
#  dense (Dense)                  (None, 128)          131200      ['flatten[0][0]']
#
#  leaky_re_lu_23 (LeakyReLU)     (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           1290        ['leaky_re_lu_23[0][0]']
#
# ==================================================================================================
# Total params: 229,962
# Trainable params: 229,962
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
opt = Adam(learning_rate=0.001)
model.compile(loss = 'categorical_crossentropy', optimizer = opt, metrics= ['accuracy'])

# %%
model.fit(x_train, y_train, batch_size = 32, epochs = 10, shuffle=True)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 85s 39ms/step - loss: 1.9705 - accuracy: 0.3147
# Epoch 2/10
# 1563/1563 [==============================] - 61s 39ms/step - loss: 1.5759 - accuracy: 0.4412
# Epoch 3/10
# 1563/1563 [==============================] - 65s 42ms/step - loss: 1.3423 - accuracy: 0.5257
# Epoch 4/10
# 1563/1563 [==============================] - 61s 39ms/step - loss: 1.1829 - accuracy: 0.5842
# Epoch 5/10
# 1563/1563 [==============================] - 61s 39ms/step - loss: 1.0516 - accuracy: 0.6316
# Epoch 6/10
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.9464 - accuracy: 0.6702
# Epoch 7/10
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.8519 - accuracy: 0.7036
# Epoch 8/10
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.7703 - accuracy: 0.7304
# Epoch 9/10
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.6977 - accuracy: 0.7549
# Epoch 10/10
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.6274 - accuracy: 0.7807

# %%
model.evaluate(x_test, y_test, batch_size=1000)
# Out:
# 10/10 [==============================] - 2s 60ms/step - loss: 1.1525 - accuracy: 0.6385
# [1.1524578332901, 0.6384999752044678]

# %%
model.evaluate(x_test, y_test, batch_size=32)
# Out:
# 313/313 [==============================] - 4s 10ms/step - loss: 1.1525 - accuracy: 0.6385
# [1.1524579524993896, 0.6384999752044678]
