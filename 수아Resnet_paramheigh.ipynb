# %% [markdown]
# <a href="https://colab.research.google.com/github/suajeong52/CNN/blob/main/%EC%88%98%EC%95%84Resnet_paramheigh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
NUM_CLASSES = 10

x_train = x_train.astype('float32')/255.
x_test  = x_test.astype('float32')/255.

y_train = to_categorical(y_train)
y_test  = to_categorical(y_test)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# 170508288/170498071 [==============================] - 3s 0us/step

# %%
# !pip install git+https://www.github.com/keras-team/keras-contrib.git
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-myre6dwt
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-myre6dwt
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from keras-contrib==2.0.8) (2.8.0)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-py3-none-any.whl size=101077 sha256=35580aec3af99c7bbeffe7718acb5d0e8f1cd06163deb73cf669325b21713811
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pt6fus3w/wheels/bb/1f/f2/b57495012683b6b20bbae94a3915ec79753111452d79886abc
# Successfully built keras-contrib
# Installing collected packages: keras-contrib
# Successfully installed keras-contrib-2.0.8

# %%
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout, Concatenate, Layer, InputSpec, Activation, LeakyReLU
from tensorflow.keras.activations import sigmoid 
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError 
from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization
from tensorflow.keras.layers import UpSampling2D, Conv2D, Conv2DTranspose
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.layers import add

from tensorflow.keras.callbacks import Callback, LearningRateScheduler
from tensorflow.keras.callbacks import ModelCheckpoint
import os

# %%
class CustomCallback(Callback):
    
    def __init__(self, run_folder, print_every_n_batches, initial_epoch, vae, ):
        self.epoch = initial_epoch
        self.run_folder = run_folder
        self.print_every_n_batches = print_every_n_batches
        self.vae = vae

    def on_batch_end(self, batch, logs={}):  
      a=0
    #  if batch % self.print_every_n_batches == 0:
    #    print(batch)
     #     self.model.predict()
     #     potential_by_cnn =  model.predict(X_test)


     #       z_new = np.random.normal(size = (1,self.vae.z_dim))
     #       reconst = self.vae.decoder.predict(np.array(z_new))[0].squeeze()

      #      filepath = os.path.join(self.run_folder, 'images', 'img_' + str(self.epoch).zfill(3) + '_' + str(batch) + '.jpg')
      #      if len(reconst.shape) == 2:
      #          plt.imsave(filepath, reconst, cmap='gray_r')
      #      else:
      #          plt.imsave(filepath, reconst)

    def on_epoch_begin(self, epoch, logs={}):
        self.epoch += 1



def step_decay_schedule(initial_lr, decay_factor=0.5, step_size=1):
    '''
    Wrapper function to create a LearningRateScheduler with step decay schedule.
    '''
    def schedule(epoch):
        new_lr = initial_lr * (decay_factor ** np.floor(epoch/step_size))
        
        return new_lr

    return LearningRateScheduler(schedule)

# %%
weight_init = RandomNormal(mean=0., stddev=0.02)

def conv7s1(layer_input, filters, final):
  y = ReflectionPadding2D(padding =(3,3))(layer_input)
  y = Conv2D(filters, kernel_size=(7,7), strides=1, padding='valid', kernel_initializer = weight_init)(y)
  if final:
    y = sigmoid(y) 
  else: 
    y = LeakyReLU()(y)
    y = InstanceNormalization(axis = -1, center = False, scale = False)(y)

  return y

def downsample(layer_input,filters):
  y = Conv2D(filters, kernel_size=(3,3), strides=2, padding='same', kernel_initializer = weight_init)(layer_input)
  y = LeakyReLU()(y)
  y = InstanceNormalization(axis = -1, center = False, scale = False)(y)
  return y

def residual(layer_input, filters):
  shortcut = layer_input
  y = ReflectionPadding2D(padding =(1,1))(layer_input)
  y = Conv2D(filters, kernel_size=(3, 3), strides=1, padding='valid', kernel_initializer = weight_init)(y)
  y = LeakyReLU()(y)
  y = InstanceNormalization(axis = -1, center = False, scale = False)(y)

  y = ReflectionPadding2D(padding =(1,1))(layer_input)
  y = Conv2D(filters, kernel_size=(3, 3), strides=1, padding='valid', kernel_initializer = weight_init)(y)
  y = InstanceNormalization(axis = -1, center = False, scale = False)(y)
  return add([shortcut, y])

def upsample(layer_input,filters):
  y = Conv2DTranspose(filters, kernel_size=(3, 3), strides=2, padding='same', kernel_initializer = weight_init)(layer_input)
  y = LeakyReLU()(y)
  y = InstanceNormalization(axis = -1, center = False, scale = False)(y)
  return y

# %%
class ReflectionPadding2D(Layer):
    def __init__(self, padding=(1, 1), **kwargs):
        self.padding = tuple(padding)
        self.input_spec = [InputSpec(ndim=4)]
        super(ReflectionPadding2D, self).__init__(**kwargs)

    def compute_output_shape(self, s):
        """ If you are using "channels_last" configuration"""
        return (s[0], s[1] + 2 * self.padding[0], s[2] + 2 * self.padding[1], s[3])

    def call(self, x, mask=None):
        w_pad,h_pad = self.padding
        return tf.pad(x, [[0,0], [h_pad,h_pad], [w_pad,w_pad], [0,0] ], 'REFLECT')

# %%
gen_n_filters = 10

img = Input(shape=(32,32,3))

y = conv7s1(img, gen_n_filters, False)


y = downsample(y, gen_n_filters * 2)
for i in range(80):
  y = residual(y, gen_n_filters * 2)

y = downsample(y, gen_n_filters * 2)
for i in range(120):
  y = residual(y, gen_n_filters * 2)


y = Flatten()(y)

y = Dense(128, activation ='relu')(y)

output = Dense(10, activation = 'softmax')(y)

   
model = Model(img, output)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  reflection_padding2d (Reflecti  (None, 38, 38, 3)   0           ['input_1[0][0]']
#  onPadding2D)
#
#  conv2d (Conv2D)                (None, 32, 32, 10)   1480        ['reflection_padding2d[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 32, 32, 10)   0           ['conv2d[0][0]']
#
#  instance_normalization (Instan  (None, 32, 32, 10)  0           ['leaky_re_lu[0][0]']
#  ceNormalization)
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 20)   1820        ['instance_normalization[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 16, 16, 20)   0           ['conv2d_1[0][0]']
#
#  instance_normalization_1 (Inst  (None, 16, 16, 20)  0           ['leaky_re_lu_1[0][0]']
#  anceNormalization)
#
#  reflection_padding2d_2 (Reflec  (None, 18, 18, 20)  0           ['instance_normalization_1[0][0]'
#  tionPadding2D)                                                  ]
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 20)   3620        ['reflection_padding2d_2[0][0]']
#
#  instance_normalization_3 (Inst  (None, 16, 16, 20)  0           ['conv2d_3[0][0]']
#  anceNormalization)
#
#  add (Add)                      (None, 16, 16, 20)   0           ['instance_normalization_1[0][0]'
#                                                                  , 'instance_normalization_3[0][0]
#                                                                  ']
#
#  reflection_padding2d_4 (Reflec  (None, 18, 18, 20)  0           ['add[0][0]']
#  tionPadding2D)
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 20)   3620        ['reflection_padding2d_4[0][0]']
#
#  instance_normalization_5 (Inst  (None, 16, 16, 20)  0           ['conv2d_5[0][0]']
#  anceNormalization)
#
#  add_1 (Add)                    (None, 16, 16, 20)   0           ['add[0][0]',
#                                                                   'instance_normalization_5[0][0]'
#                                                                  ]
#
#  reflection_padding2d_6 (Reflec  (None, 18, 18, 20)  0           ['add_1[0][0]']
#  tionPadding2D)
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 20)   3620        ['reflection_padding2d_6[0][0]']
#
#  instance_normalization_7 (Inst  (None, 16, 16, 20)  0           ['conv2d_7[0][0]']
#  anceNormalization)
#
#  add_2 (Add)                    (None, 16, 16, 20)   0           ['add_1[0][0]',
#                                                                   'instance_normalization_7[0][0]'
#                                                                  ]
#
#  reflection_padding2d_8 (Reflec  (None, 18, 18, 20)  0           ['add_2[0][0]']
#  tionPadding2D)
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 20)   3620        ['reflection_padding2d_8[0][0]']
#
#  instance_normalization_9 (Inst  (None, 16, 16, 20)  0           ['conv2d_9[0][0]']
#  anceNormalization)
#
#  add_3 (Add)                    (None, 16, 16, 20)   0           ['add_2[0][0]',
#                                                                   'instance_normalization_9[0][0]'
#                                                                  ]
#
#  reflection_padding2d_10 (Refle  (None, 18, 18, 20)  0           ['add_3[0][0]']
#  ctionPadding2D)
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_10[0][0]']
#
#  instance_normalization_11 (Ins  (None, 16, 16, 20)  0           ['conv2d_11[0][0]']
#  tanceNormalization)
#
#  add_4 (Add)                    (None, 16, 16, 20)   0           ['add_3[0][0]',
#                                                                   'instance_normalization_11[0][0]
#                                                                  ']
#
#  reflection_padding2d_12 (Refle  (None, 18, 18, 20)  0           ['add_4[0][0]']
#  ctionPadding2D)
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_12[0][0]']
#
#  instance_normalization_13 (Ins  (None, 16, 16, 20)  0           ['conv2d_13[0][0]']
#  tanceNormalization)
#
#  add_5 (Add)                    (None, 16, 16, 20)   0           ['add_4[0][0]',
#                                                                   'instance_normalization_13[0][0]
#                                                                  ']
#
#  reflection_padding2d_14 (Refle  (None, 18, 18, 20)  0           ['add_5[0][0]']
#  ctionPadding2D)
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_14[0][0]']
#
#  instance_normalization_15 (Ins  (None, 16, 16, 20)  0           ['conv2d_15[0][0]']
#  tanceNormalization)
#
#  add_6 (Add)                    (None, 16, 16, 20)   0           ['add_5[0][0]',
#                                                                   'instance_normalization_15[0][0]
#                                                                  ']
#
#  reflection_padding2d_16 (Refle  (None, 18, 18, 20)  0           ['add_6[0][0]']
#  ctionPadding2D)
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_16[0][0]']
#
#  instance_normalization_17 (Ins  (None, 16, 16, 20)  0           ['conv2d_17[0][0]']
#  tanceNormalization)
#
#  add_7 (Add)                    (None, 16, 16, 20)   0           ['add_6[0][0]',
#                                                                   'instance_normalization_17[0][0]
#                                                                  ']
#
#  reflection_padding2d_18 (Refle  (None, 18, 18, 20)  0           ['add_7[0][0]']
#  ctionPadding2D)
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_18[0][0]']
#
#  instance_normalization_19 (Ins  (None, 16, 16, 20)  0           ['conv2d_19[0][0]']
#  tanceNormalization)
#
#  add_8 (Add)                    (None, 16, 16, 20)   0           ['add_7[0][0]',
#                                                                   'instance_normalization_19[0][0]
#                                                                  ']
#
#  reflection_padding2d_20 (Refle  (None, 18, 18, 20)  0           ['add_8[0][0]']
#  ctionPadding2D)
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_20[0][0]']
#
#  instance_normalization_21 (Ins  (None, 16, 16, 20)  0           ['conv2d_21[0][0]']
#  tanceNormalization)
#
#  add_9 (Add)                    (None, 16, 16, 20)   0           ['add_8[0][0]',
#                                                                   'instance_normalization_21[0][0]
#                                                                  ']
#
#  reflection_padding2d_22 (Refle  (None, 18, 18, 20)  0           ['add_9[0][0]']
#  ctionPadding2D)
#
#  conv2d_23 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_22[0][0]']
#
#  instance_normalization_23 (Ins  (None, 16, 16, 20)  0           ['conv2d_23[0][0]']
#  tanceNormalization)
#
#  add_10 (Add)                   (None, 16, 16, 20)   0           ['add_9[0][0]',
#                                                                   'instance_normalization_23[0][0]
#                                                                  ']
#
#  reflection_padding2d_24 (Refle  (None, 18, 18, 20)  0           ['add_10[0][0]']
#  ctionPadding2D)
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_24[0][0]']
#
#  instance_normalization_25 (Ins  (None, 16, 16, 20)  0           ['conv2d_25[0][0]']
#  tanceNormalization)
#
#  add_11 (Add)                   (None, 16, 16, 20)   0           ['add_10[0][0]',
#                                                                   'instance_normalization_25[0][0]
#                                                                  ']
#
#  reflection_padding2d_26 (Refle  (None, 18, 18, 20)  0           ['add_11[0][0]']
#  ctionPadding2D)
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_26[0][0]']
#
#  instance_normalization_27 (Ins  (None, 16, 16, 20)  0           ['conv2d_27[0][0]']
#  tanceNormalization)
#
#  add_12 (Add)                   (None, 16, 16, 20)   0           ['add_11[0][0]',
#                                                                   'instance_normalization_27[0][0]
#                                                                  ']
#
#  reflection_padding2d_28 (Refle  (None, 18, 18, 20)  0           ['add_12[0][0]']
#  ctionPadding2D)
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_28[0][0]']
#
#  instance_normalization_29 (Ins  (None, 16, 16, 20)  0           ['conv2d_29[0][0]']
#  tanceNormalization)
#
#  add_13 (Add)                   (None, 16, 16, 20)   0           ['add_12[0][0]',
#                                                                   'instance_normalization_29[0][0]
#                                                                  ']
#
#  reflection_padding2d_30 (Refle  (None, 18, 18, 20)  0           ['add_13[0][0]']
#  ctionPadding2D)
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_30[0][0]']
#
#  instance_normalization_31 (Ins  (None, 16, 16, 20)  0           ['conv2d_31[0][0]']
#  tanceNormalization)
#
#  add_14 (Add)                   (None, 16, 16, 20)   0           ['add_13[0][0]',
#                                                                   'instance_normalization_31[0][0]
#                                                                  ']
#
#  reflection_padding2d_32 (Refle  (None, 18, 18, 20)  0           ['add_14[0][0]']
#  ctionPadding2D)
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_32[0][0]']
#
#  instance_normalization_33 (Ins  (None, 16, 16, 20)  0           ['conv2d_33[0][0]']
#  tanceNormalization)
#
#  add_15 (Add)                   (None, 16, 16, 20)   0           ['add_14[0][0]',
#                                                                   'instance_normalization_33[0][0]
#                                                                  ']
#
#  reflection_padding2d_34 (Refle  (None, 18, 18, 20)  0           ['add_15[0][0]']
#  ctionPadding2D)
#
#  conv2d_35 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_34[0][0]']
#
#  instance_normalization_35 (Ins  (None, 16, 16, 20)  0           ['conv2d_35[0][0]']
#  tanceNormalization)
#
#  add_16 (Add)                   (None, 16, 16, 20)   0           ['add_15[0][0]',
#                                                                   'instance_normalization_35[0][0]
#                                                                  ']
#
#  reflection_padding2d_36 (Refle  (None, 18, 18, 20)  0           ['add_16[0][0]']
#  ctionPadding2D)
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_36[0][0]']
#
#  instance_normalization_37 (Ins  (None, 16, 16, 20)  0           ['conv2d_37[0][0]']
#  tanceNormalization)
#
#  add_17 (Add)                   (None, 16, 16, 20)   0           ['add_16[0][0]',
#                                                                   'instance_normalization_37[0][0]
#                                                                  ']
#
#  reflection_padding2d_38 (Refle  (None, 18, 18, 20)  0           ['add_17[0][0]']
#  ctionPadding2D)
#
#  conv2d_39 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_38[0][0]']
#
#  instance_normalization_39 (Ins  (None, 16, 16, 20)  0           ['conv2d_39[0][0]']
#  tanceNormalization)
#
#  add_18 (Add)                   (None, 16, 16, 20)   0           ['add_17[0][0]',
#                                                                   'instance_normalization_39[0][0]
#                                                                  ']
#
#  reflection_padding2d_40 (Refle  (None, 18, 18, 20)  0           ['add_18[0][0]']
#  ctionPadding2D)
#
#  conv2d_41 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_40[0][0]']
#
#  instance_normalization_41 (Ins  (None, 16, 16, 20)  0           ['conv2d_41[0][0]']
#  tanceNormalization)
#
#  add_19 (Add)                   (None, 16, 16, 20)   0           ['add_18[0][0]',
#                                                                   'instance_normalization_41[0][0]
#                                                                  ']
#
#  reflection_padding2d_42 (Refle  (None, 18, 18, 20)  0           ['add_19[0][0]']
#  ctionPadding2D)
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_42[0][0]']
#
#  instance_normalization_43 (Ins  (None, 16, 16, 20)  0           ['conv2d_43[0][0]']
#  tanceNormalization)
#
#  add_20 (Add)                   (None, 16, 16, 20)   0           ['add_19[0][0]',
#                                                                   'instance_normalization_43[0][0]
#                                                                  ']
#
#  reflection_padding2d_44 (Refle  (None, 18, 18, 20)  0           ['add_20[0][0]']
#  ctionPadding2D)
#
#  conv2d_45 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_44[0][0]']
#
#  instance_normalization_45 (Ins  (None, 16, 16, 20)  0           ['conv2d_45[0][0]']
#  tanceNormalization)
#
#  add_21 (Add)                   (None, 16, 16, 20)   0           ['add_20[0][0]',
#                                                                   'instance_normalization_45[0][0]
#                                                                  ']
#
#  reflection_padding2d_46 (Refle  (None, 18, 18, 20)  0           ['add_21[0][0]']
#  ctionPadding2D)
#
#  conv2d_47 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_46[0][0]']
#
#  instance_normalization_47 (Ins  (None, 16, 16, 20)  0           ['conv2d_47[0][0]']
#  tanceNormalization)
#
#  add_22 (Add)                   (None, 16, 16, 20)   0           ['add_21[0][0]',
#                                                                   'instance_normalization_47[0][0]
#                                                                  ']
#
#  reflection_padding2d_48 (Refle  (None, 18, 18, 20)  0           ['add_22[0][0]']
#  ctionPadding2D)
#
#  conv2d_49 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_48[0][0]']
#
#  instance_normalization_49 (Ins  (None, 16, 16, 20)  0           ['conv2d_49[0][0]']
#  tanceNormalization)
#
#  add_23 (Add)                   (None, 16, 16, 20)   0           ['add_22[0][0]',
#                                                                   'instance_normalization_49[0][0]
#                                                                  ']
#
#  reflection_padding2d_50 (Refle  (None, 18, 18, 20)  0           ['add_23[0][0]']
#  ctionPadding2D)
#
#  conv2d_51 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_50[0][0]']
#
#  instance_normalization_51 (Ins  (None, 16, 16, 20)  0           ['conv2d_51[0][0]']
#  tanceNormalization)
#
#  add_24 (Add)                   (None, 16, 16, 20)   0           ['add_23[0][0]',
#                                                                   'instance_normalization_51[0][0]
#                                                                  ']
#
#  reflection_padding2d_52 (Refle  (None, 18, 18, 20)  0           ['add_24[0][0]']
#  ctionPadding2D)
#
#  conv2d_53 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_52[0][0]']
#
#  instance_normalization_53 (Ins  (None, 16, 16, 20)  0           ['conv2d_53[0][0]']
#  tanceNormalization)
#
#  add_25 (Add)                   (None, 16, 16, 20)   0           ['add_24[0][0]',
#                                                                   'instance_normalization_53[0][0]
#                                                                  ']
#
#  reflection_padding2d_54 (Refle  (None, 18, 18, 20)  0           ['add_25[0][0]']
#  ctionPadding2D)
#
#  conv2d_55 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_54[0][0]']
#
#  instance_normalization_55 (Ins  (None, 16, 16, 20)  0           ['conv2d_55[0][0]']
#  tanceNormalization)
#
#  add_26 (Add)                   (None, 16, 16, 20)   0           ['add_25[0][0]',
#                                                                   'instance_normalization_55[0][0]
#                                                                  ']
#
#  reflection_padding2d_56 (Refle  (None, 18, 18, 20)  0           ['add_26[0][0]']
#  ctionPadding2D)
#
#  conv2d_57 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_56[0][0]']
#
#  instance_normalization_57 (Ins  (None, 16, 16, 20)  0           ['conv2d_57[0][0]']
#  tanceNormalization)
#
#  add_27 (Add)                   (None, 16, 16, 20)   0           ['add_26[0][0]',
#                                                                   'instance_normalization_57[0][0]
#                                                                  ']
#
#  reflection_padding2d_58 (Refle  (None, 18, 18, 20)  0           ['add_27[0][0]']
#  ctionPadding2D)
#
#  conv2d_59 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_58[0][0]']
#
#  instance_normalization_59 (Ins  (None, 16, 16, 20)  0           ['conv2d_59[0][0]']
#  tanceNormalization)
#
#  add_28 (Add)                   (None, 16, 16, 20)   0           ['add_27[0][0]',
#                                                                   'instance_normalization_59[0][0]
#                                                                  ']
#
#  reflection_padding2d_60 (Refle  (None, 18, 18, 20)  0           ['add_28[0][0]']
#  ctionPadding2D)
#
#  conv2d_61 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_60[0][0]']
#
#  instance_normalization_61 (Ins  (None, 16, 16, 20)  0           ['conv2d_61[0][0]']
#  tanceNormalization)
#
#  add_29 (Add)                   (None, 16, 16, 20)   0           ['add_28[0][0]',
#                                                                   'instance_normalization_61[0][0]
#                                                                  ']
#
#  reflection_padding2d_62 (Refle  (None, 18, 18, 20)  0           ['add_29[0][0]']
#  ctionPadding2D)
#
#  conv2d_63 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_62[0][0]']
#
#  instance_normalization_63 (Ins  (None, 16, 16, 20)  0           ['conv2d_63[0][0]']
#  tanceNormalization)
#
#  add_30 (Add)                   (None, 16, 16, 20)   0           ['add_29[0][0]',
#                                                                   'instance_normalization_63[0][0]
#                                                                  ']
#
#  reflection_padding2d_64 (Refle  (None, 18, 18, 20)  0           ['add_30[0][0]']
#  ctionPadding2D)
#
#  conv2d_65 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_64[0][0]']
#
#  instance_normalization_65 (Ins  (None, 16, 16, 20)  0           ['conv2d_65[0][0]']
#  tanceNormalization)
#
#  add_31 (Add)                   (None, 16, 16, 20)   0           ['add_30[0][0]',
#                                                                   'instance_normalization_65[0][0]
#                                                                  ']
#
#  reflection_padding2d_66 (Refle  (None, 18, 18, 20)  0           ['add_31[0][0]']
#  ctionPadding2D)
#
#  conv2d_67 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_66[0][0]']
#
#  instance_normalization_67 (Ins  (None, 16, 16, 20)  0           ['conv2d_67[0][0]']
#  tanceNormalization)
#
#  add_32 (Add)                   (None, 16, 16, 20)   0           ['add_31[0][0]',
#                                                                   'instance_normalization_67[0][0]
#                                                                  ']
#
#  reflection_padding2d_68 (Refle  (None, 18, 18, 20)  0           ['add_32[0][0]']
#  ctionPadding2D)
#
#  conv2d_69 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_68[0][0]']
#
#  instance_normalization_69 (Ins  (None, 16, 16, 20)  0           ['conv2d_69[0][0]']
#  tanceNormalization)
#
#  add_33 (Add)                   (None, 16, 16, 20)   0           ['add_32[0][0]',
#                                                                   'instance_normalization_69[0][0]
#                                                                  ']
#
#  reflection_padding2d_70 (Refle  (None, 18, 18, 20)  0           ['add_33[0][0]']
#  ctionPadding2D)
#
#  conv2d_71 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_70[0][0]']
#
#  instance_normalization_71 (Ins  (None, 16, 16, 20)  0           ['conv2d_71[0][0]']
#  tanceNormalization)
#
#  add_34 (Add)                   (None, 16, 16, 20)   0           ['add_33[0][0]',
#                                                                   'instance_normalization_71[0][0]
#                                                                  ']
#
#  reflection_padding2d_72 (Refle  (None, 18, 18, 20)  0           ['add_34[0][0]']
#  ctionPadding2D)
#
#  conv2d_73 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_72[0][0]']
#
#  instance_normalization_73 (Ins  (None, 16, 16, 20)  0           ['conv2d_73[0][0]']
#  tanceNormalization)
#
#  add_35 (Add)                   (None, 16, 16, 20)   0           ['add_34[0][0]',
#                                                                   'instance_normalization_73[0][0]
#                                                                  ']
#
#  reflection_padding2d_74 (Refle  (None, 18, 18, 20)  0           ['add_35[0][0]']
#  ctionPadding2D)
#
#  conv2d_75 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_74[0][0]']
#
#  instance_normalization_75 (Ins  (None, 16, 16, 20)  0           ['conv2d_75[0][0]']
#  tanceNormalization)
#
#  add_36 (Add)                   (None, 16, 16, 20)   0           ['add_35[0][0]',
#                                                                   'instance_normalization_75[0][0]
#                                                                  ']
#
#  reflection_padding2d_76 (Refle  (None, 18, 18, 20)  0           ['add_36[0][0]']
#  ctionPadding2D)
#
#  conv2d_77 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_76[0][0]']
#
#  instance_normalization_77 (Ins  (None, 16, 16, 20)  0           ['conv2d_77[0][0]']
#  tanceNormalization)
#
#  add_37 (Add)                   (None, 16, 16, 20)   0           ['add_36[0][0]',
#                                                                   'instance_normalization_77[0][0]
#                                                                  ']
#
#  reflection_padding2d_78 (Refle  (None, 18, 18, 20)  0           ['add_37[0][0]']
#  ctionPadding2D)
#
#  conv2d_79 (Conv2D)             (None, 16, 16, 20)   3620        ['reflection_padding2d_78[0][0]']
#
#  instance_normalization_79 (Ins  (None, 16, 16, 20)  0           ['conv2d_79[0][0]']
# ...
#                                                                  ]
#
#  instance_normalization_380 (In  (None, 8, 8, 20)    0           ['conv2d_380[0][0]']
#  stanceNormalization)
#
#  add_188 (Add)                  (None, 8, 8, 20)     0           ['add_187[0][0]',
#                                                                   'instance_normalization_380[0][0
#                                                                  ]']
#
#  reflection_padding2d_380 (Refl  (None, 10, 10, 20)  0           ['add_188[0][0]']
#  ectionPadding2D)
#
#  conv2d_382 (Conv2D)            (None, 8, 8, 20)     3620        ['reflection_padding2d_380[0][0]'
#                                                                  ]
#
#  instance_normalization_382 (In  (None, 8, 8, 20)    0           ['conv2d_382[0][0]']
#  stanceNormalization)
#
#  add_189 (Add)                  (None, 8, 8, 20)     0           ['add_188[0][0]',
#                                                                   'instance_normalization_382[0][0
#                                                                  ]']
#
#  reflection_padding2d_382 (Refl  (None, 10, 10, 20)  0           ['add_189[0][0]']
#  ectionPadding2D)
#
#  conv2d_384 (Conv2D)            (None, 8, 8, 20)     3620        ['reflection_padding2d_382[0][0]'
#                                                                  ]
#
#  instance_normalization_384 (In  (None, 8, 8, 20)    0           ['conv2d_384[0][0]']
#  stanceNormalization)
#
#  add_190 (Add)                  (None, 8, 8, 20)     0           ['add_189[0][0]',
#                                                                   'instance_normalization_384[0][0
#                                                                  ]']
#
#  reflection_padding2d_384 (Refl  (None, 10, 10, 20)  0           ['add_190[0][0]']
#  ectionPadding2D)
#
#  conv2d_386 (Conv2D)            (None, 8, 8, 20)     3620        ['reflection_padding2d_384[0][0]'
#                                                                  ]
#
#  instance_normalization_386 (In  (None, 8, 8, 20)    0           ['conv2d_386[0][0]']
#  stanceNormalization)
#
#  add_191 (Add)                  (None, 8, 8, 20)     0           ['add_190[0][0]',
#                                                                   'instance_normalization_386[0][0
#                                                                  ]']
#
#  reflection_padding2d_386 (Refl  (None, 10, 10, 20)  0           ['add_191[0][0]']
#  ectionPadding2D)
#
#  conv2d_388 (Conv2D)            (None, 8, 8, 20)     3620        ['reflection_padding2d_386[0][0]'
#                                                                  ]
#
#  instance_normalization_388 (In  (None, 8, 8, 20)    0           ['conv2d_388[0][0]']
#  stanceNormalization)
#
#  add_192 (Add)                  (None, 8, 8, 20)     0           ['add_191[0][0]',
#                                                                   'instance_normalization_388[0][0
#                                                                  ]']
#
#  reflection_padding2d_388 (Refl  (None, 10, 10, 20)  0           ['add_192[0][0]']
#  ectionPadding2D)
#
#  conv2d_390 (Conv2D)            (None, 8, 8, 20)     3620        ['reflection_padding2d_388[0][0]'
#                                                                  ]
#
#  instance_normalization_390 (In  (None, 8, 8, 20)    0           ['conv2d_390[0][0]']
#  stanceNormalization)
#
#  add_193 (Add)                  (None, 8, 8, 20)     0           ['add_192[0][0]',
#                                                                   'instance_normalization_390[0][0
#                                                                  ]']
#
#  reflection_padding2d_390 (Refl  (None, 10, 10, 20)  0           ['add_193[0][0]']
#  ectionPadding2D)
#
#  conv2d_392 (Conv2D)            (None, 8, 8, 20)     3620        ['reflection_padding2d_390[0][0]'
#                                                                  ]
#
#  instance_normalization_392 (In  (None, 8, 8, 20)    0           ['conv2d_392[0][0]']
#  stanceNormalization)
#
#  add_194 (Add)                  (None, 8, 8, 20)     0           ['add_193[0][0]',
#                                                                   'instance_normalization_392[0][0
#                                                                  ]']
#
#  reflection_padding2d_392 (Refl  (None, 10, 10, 20)  0           ['add_194[0][0]']
#  ectionPadding2D)
#
#  conv2d_394 (Conv2D)            (None, 8, 8, 20)     3620        ['reflection_padding2d_392[0][0]'
#                                                                  ]
#
#  instance_normalization_394 (In  (None, 8, 8, 20)    0           ['conv2d_394[0][0]']
#  stanceNormalization)
#
#  add_195 (Add)                  (None, 8, 8, 20)     0           ['add_194[0][0]',
#                                                                   'instance_normalization_394[0][0
#                                                                  ]']
#
#  reflection_padding2d_394 (Refl  (None, 10, 10, 20)  0           ['add_195[0][0]']
#  ectionPadding2D)
#
#  conv2d_396 (Conv2D)            (None, 8, 8, 20)     3620        ['reflection_padding2d_394[0][0]'
#                                                                  ]
#
#  instance_normalization_396 (In  (None, 8, 8, 20)    0           ['conv2d_396[0][0]']
#  stanceNormalization)
#
#  add_196 (Add)                  (None, 8, 8, 20)     0           ['add_195[0][0]',
#                                                                   'instance_normalization_396[0][0
#                                                                  ]']
#
#  reflection_padding2d_396 (Refl  (None, 10, 10, 20)  0           ['add_196[0][0]']
#  ectionPadding2D)
#
#  conv2d_398 (Conv2D)            (None, 8, 8, 20)     3620        ['reflection_padding2d_396[0][0]'
#                                                                  ]
#
#  instance_normalization_398 (In  (None, 8, 8, 20)    0           ['conv2d_398[0][0]']
#  stanceNormalization)
#
#  add_197 (Add)                  (None, 8, 8, 20)     0           ['add_196[0][0]',
#                                                                   'instance_normalization_398[0][0
#                                                                  ]']
#
#  reflection_padding2d_398 (Refl  (None, 10, 10, 20)  0           ['add_197[0][0]']
#  ectionPadding2D)
#
#  conv2d_400 (Conv2D)            (None, 8, 8, 20)     3620        ['reflection_padding2d_398[0][0]'
#                                                                  ]
#
#  instance_normalization_400 (In  (None, 8, 8, 20)    0           ['conv2d_400[0][0]']
#  stanceNormalization)
#
#  add_198 (Add)                  (None, 8, 8, 20)     0           ['add_197[0][0]',
#                                                                   'instance_normalization_400[0][0
#                                                                  ]']
#
#  reflection_padding2d_400 (Refl  (None, 10, 10, 20)  0           ['add_198[0][0]']
#  ectionPadding2D)
#
#  conv2d_402 (Conv2D)            (None, 8, 8, 20)     3620        ['reflection_padding2d_400[0][0]'
#                                                                  ]
#
#  instance_normalization_402 (In  (None, 8, 8, 20)    0           ['conv2d_402[0][0]']
#  stanceNormalization)
#
#  add_199 (Add)                  (None, 8, 8, 20)     0           ['add_198[0][0]',
#                                                                   'instance_normalization_402[0][0
#                                                                  ]']
#
#  flatten (Flatten)              (None, 1280)         0           ['add_199[0][0]']
#
#  dense (Dense)                  (None, 128)          163968      ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 10)           1290        ['dense[0][0]']
#
# ==================================================================================================
# Total params: 896,178
# Trainable params: 896,178
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
opt = Adam(learning_rate=0.001)
model.compile(loss = 'categorical_crossentropy', optimizer = opt, metrics= ['accuracy'])

# %%
model.fit(x_train, y_train, batch_size = 32, epochs = 50, shuffle=True, validation_split=0.1)
# Out:
# Epoch 1/50
# 1407/1407 [==============================] - 512s 307ms/step - loss: 2.5878 - accuracy: 0.2577 - val_loss: 1.9202 - val_accuracy: 0.3100
# Epoch 2/50
# 1407/1407 [==============================] - 423s 301ms/step - loss: 1.8095 - accuracy: 0.3528 - val_loss: 1.7369 - val_accuracy: 0.3704
# Epoch 3/50
# 1407/1407 [==============================] - 421s 299ms/step - loss: 1.6642 - accuracy: 0.4045 - val_loss: 1.6555 - val_accuracy: 0.4070
# Epoch 4/50
# 1407/1407 [==============================] - 421s 299ms/step - loss: 1.5603 - accuracy: 0.4419 - val_loss: 1.5123 - val_accuracy: 0.4578
# Epoch 5/50
# 1407/1407 [==============================] - 420s 299ms/step - loss: 1.4707 - accuracy: 0.4735 - val_loss: 1.4496 - val_accuracy: 0.4778
# Epoch 6/50
# 1407/1407 [==============================] - 420s 299ms/step - loss: 1.3896 - accuracy: 0.5062 - val_loss: 1.4170 - val_accuracy: 0.4974
# Epoch 7/50
# 1407/1407 [==============================] - 420s 299ms/step - loss: 1.3158 - accuracy: 0.5341 - val_loss: 1.3565 - val_accuracy: 0.5094
# Epoch 8/50
# 1407/1407 [==============================] - 420s 299ms/step - loss: 1.2458 - accuracy: 0.5558 - val_loss: 1.3334 - val_accuracy: 0.5324
# Epoch 9/50
# 1407/1407 [==============================] - 421s 299ms/step - loss: 1.1776 - accuracy: 0.5835 - val_loss: 1.3267 - val_accuracy: 0.5356
# Epoch 10/50
# 1407/1407 [==============================] - 420s 299ms/step - loss: 1.1174 - accuracy: 0.6029 - val_loss: 1.3331 - val_accuracy: 0.5394
# Epoch 11/50
# 1407/1407 [==============================] - 420s 298ms/step - loss: 1.0465 - accuracy: 0.6292 - val_loss: 1.3418 - val_accuracy: 0.5376
# Epoch 12/50
# 1407/1407 [==============================] - 421s 299ms/step - loss: 0.9840 - accuracy: 0.6508 - val_loss: 1.3237 - val_accuracy: 0.5528
# Epoch 13/50
# 1407/1407 [==============================] - 420s 298ms/step - loss: 0.9211 - accuracy: 0.6726 - val_loss: 1.3442 - val_accuracy: 0.5556
# Epoch 14/50
# 1407/1407 [==============================] - 418s 297ms/step - loss: 0.8623 - accuracy: 0.6933 - val_loss: 1.3901 - val_accuracy: 0.5486
# Epoch 15/50
# 1407/1407 [==============================] - 416s 296ms/step - loss: 0.7980 - accuracy: 0.7136 - val_loss: 1.4090 - val_accuracy: 0.5506
# Epoch 16/50
# 1407/1407 [==============================] - 418s 297ms/step - loss: 0.7421 - accuracy: 0.7344 - val_loss: 1.4235 - val_accuracy: 0.5508
# Epoch 17/50
# 1407/1407 [==============================] - 418s 297ms/step - loss: 0.6857 - accuracy: 0.7537 - val_loss: 1.4915 - val_accuracy: 0.5584
# Epoch 18/50
# 1407/1407 [==============================] - 418s 297ms/step - loss: 0.6269 - accuracy: 0.7750 - val_loss: 1.5815 - val_accuracy: 0.5520
# Epoch 19/50
# 1407/1407 [==============================] - 415s 295ms/step - loss: 0.5828 - accuracy: 0.7901 - val_loss: 1.6762 - val_accuracy: 0.5528
# Epoch 20/50
# 1407/1407 [==============================] - 418s 297ms/step - loss: 0.5373 - accuracy: 0.8068 - val_loss: 1.6900 - val_accuracy: 0.5428
# Epoch 21/50
# 1407/1407 [==============================] - 420s 298ms/step - loss: 0.4921 - accuracy: 0.8239 - val_loss: 1.9301 - val_accuracy: 0.5438
# Epoch 22/50
# 1407/1407 [==============================] - 419s 298ms/step - loss: 0.4523 - accuracy: 0.8385 - val_loss: 1.9155 - val_accuracy: 0.5450
# Epoch 23/50
# 1407/1407 [==============================] - 419s 298ms/step - loss: 0.4216 - accuracy: 0.8472 - val_loss: 2.0302 - val_accuracy: 0.5410
# Epoch 24/50
# 1407/1407 [==============================] - 418s 297ms/step - loss: 0.3899 - accuracy: 0.8582 - val_loss: 2.0616 - val_accuracy: 0.5400
# Epoch 25/50
# 1407/1407 [==============================] - 417s 297ms/step - loss: 0.3599 - accuracy: 0.8718 - val_loss: 2.1025 - val_accuracy: 0.5478
# Epoch 26/50
# 1407/1407 [==============================] - 419s 298ms/step - loss: 0.3286 - accuracy: 0.8798 - val_loss: 2.2053 - val_accuracy: 0.5376
# Epoch 27/50
# 1407/1407 [==============================] - 421s 299ms/step - loss: 0.3079 - accuracy: 0.8903 - val_loss: 2.3503 - val_accuracy: 0.5308
# Epoch 28/50
# 1407/1407 [==============================] - 422s 300ms/step - loss: 0.2934 - accuracy: 0.8934 - val_loss: 2.5078 - val_accuracy: 0.5378
# Epoch 29/50
# 1407/1407 [==============================] - 420s 299ms/step - loss: 0.2705 - accuracy: 0.9030 - val_loss: 2.5264 - val_accuracy: 0.5352
# Epoch 30/50
# 1407/1407 [==============================] - 421s 299ms/step - loss: 0.2497 - accuracy: 0.9112 - val_loss: 2.7041 - val_accuracy: 0.5230
# Epoch 31/50
# 1407/1407 [==============================] - 420s 298ms/step - loss: 0.2420 - accuracy: 0.9138 - val_loss: 2.7733 - val_accuracy: 0.5306
# Epoch 32/50
# 1407/1407 [==============================] - 420s 299ms/step - loss: 0.2297 - accuracy: 0.9172 - val_loss: 2.7954 - val_accuracy: 0.5360
# Epoch 33/50
# 1407/1407 [==============================] - 420s 298ms/step - loss: 0.2080 - accuracy: 0.9256 - val_loss: 2.9914 - val_accuracy: 0.5396
# Epoch 34/50
# 1407/1407 [==============================] - 421s 299ms/step - loss: 0.2136 - accuracy: 0.9235 - val_loss: 2.9978 - val_accuracy: 0.5428
# Epoch 35/50
# 1407/1407 [==============================] - 420s 299ms/step - loss: 0.1947 - accuracy: 0.9320 - val_loss: 3.0093 - val_accuracy: 0.5392
# Epoch 36/50
# 1407/1407 [==============================] - 421s 299ms/step - loss: 0.1745 - accuracy: 0.9375 - val_loss: 3.1829 - val_accuracy: 0.5346
# Epoch 37/50
# 1407/1407 [==============================] - 420s 299ms/step - loss: 0.1879 - accuracy: 0.9340 - val_loss: 3.1543 - val_accuracy: 0.5284
# Epoch 38/50
# 1407/1407 [==============================] - 419s 298ms/step - loss: 0.1680 - accuracy: 0.9403 - val_loss: 3.3077 - val_accuracy: 0.5344
# Epoch 39/50
# 1407/1407 [==============================] - 419s 298ms/step - loss: 0.1648 - accuracy: 0.9415 - val_loss: 3.3557 - val_accuracy: 0.5374
# Epoch 40/50
# 1407/1407 [==============================] - 419s 298ms/step - loss: 0.1584 - accuracy: 0.9437 - val_loss: 3.4225 - val_accuracy: 0.5384
# Epoch 41/50
# 1407/1407 [==============================] - 418s 297ms/step - loss: 0.1477 - accuracy: 0.9477 - val_loss: 3.3926 - val_accuracy: 0.5396
# Epoch 42/50
# 1407/1407 [==============================] - 418s 297ms/step - loss: 0.1525 - accuracy: 0.9462 - val_loss: 3.4848 - val_accuracy: 0.5354
# Epoch 43/50
# 1407/1407 [==============================] - 420s 298ms/step - loss: 0.1511 - accuracy: 0.9469 - val_loss: 3.6162 - val_accuracy: 0.5308
# Epoch 44/50
# 1407/1407 [==============================] - 418s 297ms/step - loss: 0.1376 - accuracy: 0.9531 - val_loss: 3.7049 - val_accuracy: 0.5304
# Epoch 45/50
# 1407/1407 [==============================] - 420s 298ms/step - loss: 0.1389 - accuracy: 0.9508 - val_loss: 3.4958 - val_accuracy: 0.5346
# Epoch 46/50
# 1407/1407 [==============================] - 420s 298ms/step - loss: 0.1340 - accuracy: 0.9540 - val_loss: 3.7396 - val_accuracy: 0.5358
# Epoch 47/50
# 1407/1407 [==============================] - 418s 297ms/step - loss: 0.1249 - accuracy: 0.9559 - val_loss: 3.7853 - val_accuracy: 0.5358
# Epoch 48/50
# 1407/1407 [==============================] - 418s 297ms/step - loss: 0.1333 - accuracy: 0.9531 - val_loss: 3.7037 - val_accuracy: 0.5386
# Epoch 49/50
# 1407/1407 [==============================] - 418s 297ms/step - loss: 0.1176 - accuracy: 0.9588 - val_loss: 3.8225 - val_accuracy: 0.5384
# Epoch 50/50
# 1407/1407 [==============================] - 419s 298ms/step - loss: 0.1255 - accuracy: 0.9565 - val_loss: 3.8093 - val_accuracy: 0.5368

# %%
model.evaluate(x_test, y_test, batch_size=1000)
# Out:
# 10/10 [==============================] - 16s 1s/step - loss: 3.9093 - accuracy: 0.5283
# [3.9093375205993652, 0.5282999873161316]
